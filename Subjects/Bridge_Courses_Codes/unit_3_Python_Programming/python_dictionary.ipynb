# %% [markdown]
# # Dictionary
# ---
#
# - Key value and pairs
# - Keys are immutable and values are mutable
# -

# %%
# empty dict
d = {}
print(d, type(d))

# Dictionary

d1 = {1:"value1",2:"value2",3:"value3",4:"value4"}
d1
# Out:
# {} <class 'dict'>
# {1: 'value1', 2: 'value2', 3: 'value3', 4: 'value4'}

# %%
# Arrays in pyhton

import numpy as np 
a = np.array((1,2,4))

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a[0] = 12.24

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a[0] = 10.2
a[1] = 9.1
a[2] = 12.1

# %%
b = np.array((1.1, 2.1, 31))

# %%
b
# Out:
# array([ 1.1,  2.1, 31. ])

# %%
# if
c = np.array((1.1, 2, 31))

# %%
c.dtype
# Out:
# dtype('float64')

# %%
even = [x for x in range(1,10) if x%2 ==0]

# %%
even
# Out:
# [2, 4, 6, 8]
